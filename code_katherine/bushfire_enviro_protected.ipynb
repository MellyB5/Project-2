# %% [markdown]
# Extract and Transform Protected Species Data

# %%
import pandas as pd

# %%
# read in data table 
file_protected = "data/animal_impact.csv"
protected = pd.read_csv(file_protected)
protected
# Out:
#           Scientific Name\n  \
# 0        Acacia awestoniana
# 1         Acacia constablei
# 2    Andersonia axilliflora
# 3            Baeckea kandos
# 4       Bertmainius colonus
# ..                      ...
# 326        Thesium australe
# 327     Westringia rupicola
# 328       Wollumbinia belli
# 329    Xerochrysum palustre
# 330  Xerothamnella herbacea
#
#                                            Common Name  \
# 0                                Stirling Range Wattle
# 1                                    Narrabarba Wattle
# 2                                     Giant Andersonia
# 3                                              a shrub
# 4         Eastern Stirling Range Pygmy Trapdoor Spider
# ..                                                 ...
# 326                         Austral Toadflax, Toadflax
# 327                                                NaN
# 328  Bell's Turtle, Western Sawshelled Turtle, Namo...
# 329               Swamp Everlasting, Swamp Paper Daisy
# 330                                                NaN
#
#     Percentage of the species modelled likely and known distribution within fire affected areas  \
# 0                                                 ?80%
# 1                                                 ?80%
# 2                                                 ?80%
# 3                                                 ?80%
# 4                                                 ?80%
# ..                                                 ...
# 326                                         10 to <30%
# 327                                         10 to <30%
# 328                                         10 to <30%
# 329                                         10 to <30%
# 330                                         10 to <30%
#
#         Type EPBC Act listed Threatened Status  \
# 0      Plant                        Vulnerable
# 1      Plant                        Vulnerable
# 2      Plant                        Endangered
# 3      Plant                        Endangered
# 4     Spider                        Vulnerable
# ..       ...                               ...
# 326    Plant                        Vulnerable
# 327    Plant                        Vulnerable
# 328  Reptile                        Vulnerable
# 329    Plant                        Vulnerable
# 330    Plant                        Endangered
#
#     EPBC Act listed Migratory Status Range states and territories
# 0                                NaN                           WA
# 1                                NaN                          NSW
# 2                                NaN                           WA
# 3                                NaN                          NSW
# 4                                NaN                           WA
# ..                               ...                          ...
# 326                              NaN      ACT, NSW, Qld, Tas, Vic
# 327                              NaN                     NSW, Qld
# 328                              NaN                     NSW, Qld
# 329                              NaN            NSW, SA, Tas, Vic
# 330                              NaN                          Qld
#
# [331 rows x 7 columns]

# %%
# rename columns for simplicity
protected.columns # to print out column names for use in creating column dictionary
column_names = {'Scientific Name\n':'scientific',
            'Common Name' : 'common',
            'Percentage of the species modelled likely and known distribution within fire affected areas' : 'distribution',
            'Type':'type',
            'EPBC Act listed Threatened Status':'status',
            'EPBC Act listed Migratory Status':'migratory',
            'Range states and territories':'states'}
protected.rename(columns = column_names, inplace = True)
protected
# Out:
#                  scientific  \
# 0        Acacia awestoniana
# 1         Acacia constablei
# 2    Andersonia axilliflora
# 3            Baeckea kandos
# 4       Bertmainius colonus
# ..                      ...
# 326        Thesium australe
# 327     Westringia rupicola
# 328       Wollumbinia belli
# 329    Xerochrysum palustre
# 330  Xerothamnella herbacea
#
#                                                 common distribution     type  \
# 0                                Stirling Range Wattle         ?80%    Plant
# 1                                    Narrabarba Wattle         ?80%    Plant
# 2                                     Giant Andersonia         ?80%    Plant
# 3                                              a shrub         ?80%    Plant
# 4         Eastern Stirling Range Pygmy Trapdoor Spider         ?80%   Spider
# ..                                                 ...          ...      ...
# 326                         Austral Toadflax, Toadflax   10 to <30%    Plant
# 327                                                NaN   10 to <30%    Plant
# 328  Bell's Turtle, Western Sawshelled Turtle, Namo...   10 to <30%  Reptile
# 329               Swamp Everlasting, Swamp Paper Daisy   10 to <30%    Plant
# 330                                                NaN   10 to <30%    Plant
#
#          status migratory                   states
# 0    Vulnerable       NaN                       WA
# 1    Vulnerable       NaN                      NSW
# 2    Endangered       NaN                       WA
# 3    Endangered       NaN                      NSW
# 4    Vulnerable       NaN                       WA
# ..          ...       ...                      ...
# 326  Vulnerable       NaN  ACT, NSW, Qld, Tas, Vic
# 327  Vulnerable       NaN                 NSW, Qld
# 328  Vulnerable       NaN                 NSW, Qld
# 329  Vulnerable       NaN        NSW, SA, Tas, Vic
# 330  Endangered       NaN                      Qld
#
# [331 rows x 7 columns]

# %%
# Explore the data
protected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331 entries, 0 to 330
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   scientific    331 non-null    object
#  1   common        271 non-null    object
#  2   distribution  331 non-null    object
#  3   type          331 non-null    object
#  4   status        327 non-null    object
#  5   migratory     5 non-null      object
#  6   states        331 non-null    object
# dtypes: object(7)
# memory usage: 18.2+ KB

# %%
protected.type.unique()
# Out:
# array(['Plant', 'Spider', 'Mammal', 'Bird', 'Reptile', 'Frog', 'Fish',
#        'Insect'], dtype=object)

# %%
protected.distribution.unique()
# Out:
# array(['?80%', '50 to <80%', '30 to <50%', '10 to <30%'], dtype=object)

# %%
protected.distribution.replace('?80%', '>80%', inplace = True)

# %%
protected.groupby(["type"]).count()
# Out:
#          scientific  common  distribution  status  migratory  states
# type
# Bird             13      13            13       9          5      13
# Fish              4       4             4       4          0       4
# Frog             14      14            14      14          0      14
# Insect            4       4             4       4          0       4
# Mammal           16      16            16      16          0      16
# Plant           272     212           272     272          0     272
# Reptile           7       7             7       7          0       7
# Spider            1       1             1       1          0       1

# %%
# drop the plant data
protected_animals = protected[protected["type"]!="Plant"]
protected_animals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59 entries, 4 to 328
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   scientific    59 non-null     object
#  1   common        59 non-null     object
#  2   distribution  59 non-null     object
#  3   type          59 non-null     object
#  4   status        55 non-null     object
#  5   migratory     5 non-null      object
#  6   states        59 non-null     object
# dtypes: object(7)
# memory usage: 3.7+ KB

# %%
protected_animals = protected_animals.fillna(0)

# %%
# reset index ready to convert df to json format
protected_animals.reset_index(inplace = True, drop = True)

# %%
# export data
protected_animals.to_csv('data/protected_animals.csv', index = False)

# %%
# convert transformed animal table to json to use with d3
protected_animals.to_json('data/protected_animals.json', orient = "index")

# %%
from sqlalchemy import create_engine
from config import postgresql_pword

# %%
# create engine
engine = create_engine(f'postgresql://postgres:{postgresql_pword}@localhost:5432/Project-2')
table_names = engine.table_names()
print(table_names)
# Out:
# ['protected_animals']
# C:\Users\kathe\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
protected_animals.columns
# Out:
# Index(['scientific', 'common', 'distribution', 'type', 'status', 'migratory',
#        'states'],
#       dtype='object')

# %%
protected_animals.to_sql(name="protected_animals", con=engine, if_exists='append', index=False)
